# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy

from PIL import Image
import requests
from io import BytesIO

# %%
x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y2 = np.array([170, 100, 90, 120, 50])

response = requests.get("https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png")
image_file = BytesIO(response.content)
image = Image.open(image_file)

# import requests
# from io import BytesIO
# from PIL import Image

# # Step 1: Check the URL
# url = "https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png"
# print(f"Fetching image from: {url}")

# # Step 2: Make the request and check the status code
# response = requests.get(url)
# print(f"Response status code: {response.status_code}")

# # Step 3: Check the response content
# print(f"First 100 bytes of response: {response.content[:100]}")

# # Step 4: Save the image to disk for manual inspection
# with open("luffy.png", "wb") as f:
#     f.write(response.content)
# print("Image saved to 'luffy.png'. Please check the file manually.")

# # Step 5: Try opening the image
# try:
#     image_file = BytesIO(response.content)
#     image = Image.open(image_file)
#     print("Image successfully opened!")
#     image.show()  # Display the image
# except Exception as e:
#     print(f"Error opening image: {e}")

# %%
fig, ax = plt.subplots(figsize=(7,3))
ax.plot (x, y2, color = "red")

ax_image = fig.add_axes([0.1, 0.11, 0.15, 0.35])

ax_image.imshow(image)
ax_image.axis("off")
# Out:
# (-0.5, 219.5, 425.5, -0.5)
